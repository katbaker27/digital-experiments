# %%
# ensure notebook always loaded in same state
# !rm -rf experiments/train_model

# %% [markdown]
# # Asynchronous, Offline Optimization
#
# We first set up a toy problem: 1D linear regression

# %%
import numpy as np
from digital_experiments import experiment

np.random.seed(2)
X = np.random.rand(200) * 10
y = 2 * X + 3 + np.random.randn(200)

@experiment(verbose=False, backend="csv")
def train_model(m, c):
    model = lambda x: m * x + c

    yhat = model(X)
    absolute_errors = np.abs(yhat - y)

    return {
        "mae": absolute_errors.mean(), 
        "rmse": (absolute_errors**2).mean() ** 0.5,
    }

# %% [markdown]
# What does our data look like?

# %%
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.figsize'] = [5, 5]

plt.figure(figsize=(4, 2))
plt.scatter(X, y, linewidths=0, s=10, c='k', alpha=0.5);

# %% [markdown]
# # Manual Runs

# %%
# KB comments
# I think it would be best to add some description of why you're showing the manual runs (ie why are you showing 3 runs rather than just 1?)
# maybe printing/outputting the errors from each of the three runs of the model would make this clearer
# or reminding the user of the target values of m and c and showing that the manual runs have quite high error

train_model(m=0, c=0)
train_model(m=5, c=5)
train_model(m=0, c=5)
# Out:
# {'mae': 7.6705099597961715, 'rmse': 9.2525485924273}

# %% [markdown]
# # Automated Optimization
#
# We can automatically optimize the hyperparameters of our model using successive calls to `digital_experiments.optimize_step_for`.
#
# Under the hood, this reads all previous calls to our function, and generates either
# - new random points to sample
# - new points using Bayesian Optmization to minimize the functions value
#
# Importantly, `optimize_step` is stateless: we could run this in successive python sessions.

# %%
from digital_experiments.optmization import optimize_step_for, Real

space = {
    "m": Real(0, 5),
    "c": Real(0, 5),
}

random_points = 10
opt_points = 6

# KB comments
# it is hard to tell what opt_points is being used for until seeing the graph below
# A sentence explaining that the model runs through a defined number of random points and then subsequently moves on to the defined number of bayesian optimization points in the same loop would be much more helpful

for i in range(random_points + opt_points):
    optimize_step_for(
        train_model, 
        loss_fn=lambda results: results['rmse'], 
        n_random_points=random_points, 
        space=space
    )

# %% [markdown]
# # How did we do?

# %% [markdown]
# What is the best choice for m and c that we have found? Remember the true values are 2 and 3 respectively.

# %%
from digital_experiments import experiments_for

experiments = experiments_for(train_model)
experiments.sort(key=lambda e: e.result['rmse'])
experiments[0].config
# Out:
# {'m': 2.0039097793385565, 'c': 3.0525742632866626}

# %% [markdown]
# We can see how our accuracy improved with time:

# %%
from digital_experiments.plots import track_minimization
    
plt.figure(figsize=(4, 3))
track_minimization(train_model, lambda results: results["rmse"])
plt.ylabel("RMSE")
plt.yscale("log");

# KB comments
# a legend to explain that the darker line is showing the performance of the best choice so far would be helpful to make this clearer

# %% [markdown]
# ... and also where in search space the guesses happened:

# %%
from digital_experiments.plots import track_trials  

def tidy_up(*args):
    plt.xlim(-1, 6)
    plt.ylim(-1, 6)
    plt.scatter([2], [3], c='k', marker="+", label="True Model")
    plt.gca().set_aspect("equal")

track_trials("m", "c", train_model, tidy_up, fps=2)
# Out:
# <img src="data:image/gif;base64,..." width=480px/>
